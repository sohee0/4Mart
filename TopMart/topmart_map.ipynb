# %%
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.font_manager as fm
import urllib.request
from matplotlib import rc
from bs4 import BeautifulSoup
import folium

# %%
topmart_df = pd.read_csv('./topmart_shop_info_loc.csv', encoding='utf-8')
topmart_df.tail()
# Out:
#         store                          address   Latitude   Longitude  \
# 72   탑마트 서진주점      경상남도 진주시 새평거로 136 (평거동 921)  35.181392  128.069798
# 73    탑마트 대구점  대구광역시 중구 중앙대로 66길 20 (효성해링턴 지하)  35.862074  128.594685
# 74   탑마트 물금역점  경상남도 양산시 물금읍 물금중앙길 18 (구, 물금시장)  35.309926  128.984952
# 75  탑마트 경주용강점          경상북도 경주시 산업로 4348 (용강동)  35.870536  129.231939
# 76    탑마트 부곡점     부산광역시 금정구 부곡동 79 (부곡동 333-1)  35.223140  129.090565
#
#                tel
# 72    055)743-6300
# 73    053)251-5000
# 74    055-387-3008
# 75  054)744-5501~2
# 76  051)583-1501~2

# %%
lotte_df=pd.read_csv('C:/MartRepository/4Mart/data/lotte.csv',encoding='utf-8')
lotte_df.head(3)
# Out:
#              store                                 address   Latitude  \
# 0     롯데마트 TRU동부산점      부산광역시 기장군 기장읍 기장해안로 147 롯데몰동부산점 3층  35.218819
# 1      롯데마트 TRU파주점  경기도 파주시 문발로 302 A블럭 3층(문발동, 롯데프리미엄아울렛)  37.720410
# 2  롯데마트 marketD수원점                경기도 수원시 권선구 세화로 134 롯데마트  37.265378
#
#     Longitude            tel
# 0  129.231369   051-922-2500
# 1  126.693622   031-960-2750
# 2  126.995983  031-8067-2500

# %%
map = folium.Map(location=[35.2171341,129.1111094],zoom_start=10)

for i in topmart_df.index:
    lt_lat = topmart_df.loc[i,'Latitude']
    lt_long = topmart_df.loc[i,'Longitude']
    name = f"[{topmart_df.loc[i, 'store']}]"
    address = f"{topmart_df.loc[i, 'address']}"
    tel = f"{topmart_df.loc[i, 'tel']}"


    folium.Marker(location=[lt_lat,lt_long],icon=folium.Icon(icon='barcode',color='orange'),popup=f'<pre><h4>{name}</h4>\\n주소: {address}\\n Tel: {tel}</pre>').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b27d78196fbeafd405b15a750deee8e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b27d78196fbeafd405b15a750deee8e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b27d78196fbeafd405b15a750deee8e9 = L.map(
#                 &quot;map_b27d78196fbeafd405b15a750deee8e9&quot;,
#                 {
#                     center: [35.2171341, 129.1111094],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daec505ea2c5e30ba9b8b1d1c35f6c67 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b27d78196fbeafd405b15a750deee8e9);
#
#
#             var marker_1714aaa26c771f07b8ec6444784801b6 = L.marker(
#                 [35.0942098, 129.049444],
#                 {}
#             ).addTo(map_b27d78196fbeafd405b15a750deee8e9);
#
#
#             var icon_e39ed6ffc863b1dd93231467d87455ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;barcode&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1714aaa26c771f07b8ec6444784801b6.setIcon(icon_e39ed6ffc863b1dd93231467d87455ac);
#
#
#         var popup_1a298d8a81efca20faf606650674ef59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3a585301fd9cad278b9c7b4d876025c6 = $(`&lt;div id=&quot;html_3a585301fd9cad278b9c7b4d876025c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;&lt;h4&gt;[탑마트 영도봉래점]&lt;/h4&gt;\n주소: 부산광역시 영도구 태종로 194\n Tel: 051)418-2102~3&lt;/pre&gt;&lt;/div&gt;`)[0];
#             popup_1a298d8a81efca20faf606650674ef59.setContent(html_3a585301fd9cad278b9c7b4d876025c6);
#
#
#         marker_1714aaa26c771f07b8ec6444784801b6.bindPopup(popup_1a298d8a81efca20faf606650674ef59)
#         ;
#
#
#
#
#             var marker_d141dcaeeba2ce5bd5c6fdab1804fa2c = L.marker(
#                 [35.3026702, 128.7369281],
#                 {}
#             ).addTo(map_b27d78196fbeafd405b15a750deee8e9);
#
#
#             var icon_a796b1f975eb1d909b56a65ac33ab6af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;barcode&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d141dcaeeba2ce5bd5c6fdab1804fa2c.setIcon(icon_a796b1f975eb1d909b56a65ac33ab6af);
#
#
#         var popup_caecf64d50018fa825410c5c3fb5a43f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ee466b5a76d516286f051aaf3623f2d5 = $(`&lt;div id=&quot;html_ee466b5a76d516286f051aaf3623f2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;&lt;h4&gt;[탑마트 진영점]&lt;/h4&gt;\n주소: 경상남도 김해시 진영읍 진영로 221\n Tel: 055)345-0388~9&lt;/pre&gt;&lt;/div&gt;`)[0];
#             popup_caecf64d50018fa825410c5c3fb5a43f.setContent(html_ee466b5a76d516286f051aaf3623f2d5);
#
#
#         marker_d141dcaeeba2ce5bd5c6fdab1804fa2c.bindPopup(popup_caecf64d50018fa825410c5c3fb5a43f)
#         ;
#
#
#
#
#             var marker_c0be496ec93d3613ac63cdcf5860443b = L.marker(
#                 [35.2169752, 129.1107829],
#                 {}
#             ).addTo(map_b27d78196fbeafd405b15a750deee8e9);
#
#
#             var icon_5ba27df260781f61154157c771f1be48 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;barcode&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0be496ec93d3613ac63cdcf5860443b.setIcon(icon_5ba27df260781f61154157c771f1be48);
#
#
#         var popup_251a5eb42cfbc97c7131a2fa28fb0375 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4dd9470e9cfa0a8de087b6969a73b1d0 = $(`&lt;div id=&quot;html_4dd9470e9cfa0a8de087b6969a73b1d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;&lt;h4&gt;[탑마트 금사점]&lt;/h4&gt;\n주소: 부산광역시 금정구 공단서로 22 (강산병원 옆)\n Tel: 051)527-2222&lt;/pre&gt;&lt;/div&gt;`)[0];
#             popup_251a5eb42cfbc97c7131a2fa28fb0375.setContent(html_4dd9470e9cfa0a8de087b6969a73b1d0);
#
#
#         marker_c0be496ec93d3613ac63cdcf5860443b.bindPopup(popup_251a5eb42cfbc97c7131a2fa28fb0375)
#         ;
#
#
#
#
#             var marker_f0f932b99a7bd54b25249f17234811a6 = L.marker(
#                 [34.8321573, 128.4139597],
#                 {}
#             ).addTo(map_b27d78196fbeafd405b15a750deee8e9);
#
#
#             var icon_8f34c915874995f6455e2ac00d7fb5d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-r
