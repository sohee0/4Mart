# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.font_manager as fm
import folium
from matplotlib import rc

# %%
Emart_df = pd.read_csv('./Emart_info.csv',encoding='utf-8')
Emart_df.head()
# Out:
#        store              address   Latitude   Longitude            tel
# 0   이마트 가든5점     서울특별시 송파구 충민로 10  37.478232  127.119370    02-411-1234
# 1    이마트 가양점    서울특별시 강서구 양천로 559  37.557897  126.862298   02-2101-1234
# 2    이마트 강릉점  강원도 강릉시 경강로 2398-10  37.770583  128.922618   033-649-1234
# 3    이마트 검단점     인천광역시 서구 서곶로 754  37.585534  126.677194   032-440-1234
# 4  이마트 경기광주점      경기도 광주시 광주대로 30  37.409522  127.261229  031-8026-1234

# %%
map = folium.Map(location=[35.2500198,129.0907241],zoom_start=16,tiles='OpenStreetMap')
folium.Marker(location=[35.2500198,129.0907241],icon=folium.Icon(color='gray',icon='shopping-cart'),tooltip='Emart').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5696202669f0844a164b16c4d5cc4f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5696202669f0844a164b16c4d5cc4f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b5696202669f0844a164b16c4d5cc4f5 = L.map(
#                 &quot;map_b5696202669f0844a164b16c4d5cc4f5&quot;,
#                 {
#                     center: [35.2500198, 129.0907241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce2537a66ac20a082db049be8b70adbe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5696202669f0844a164b16c4d5cc4f5);
#
#
#             var marker_ffcbb76a04295904b07f8683c5c7c158 = L.marker(
#                 [35.2500198, 129.0907241],
#                 {}
#             ).addTo(map_b5696202669f0844a164b16c4d5cc4f5);
#
#
#             var icon_a8141d5bc8eb7c5b45af453993b1e8d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ffcbb76a04295904b07f8683c5c7c158.setIcon(icon_a8141d5bc8eb7c5b45af453993b1e8d3);
#
#
#             marker_ffcbb76a04295904b07f8683c5c7c158.bindTooltip(
#                 `&lt;div&gt;
#                      Emart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[35.2500198,129.0907241],zoom_start=10,tiles='OpenStreetMap')

for i in Emart_df.index:
    lt_lat = Emart_df.loc[i,'Latitude']
    lt_long = Emart_df.loc[i,'Longitude']

    title = f"{Emart_df.loc[i, 'store']}"


    color = 'gray'
    if Emart_df.loc[i,'store']=='Emart':
        color ='gray'

    folium.Marker(location=[lt_lat,lt_long],radius=5,color=color,icon=folium.Icon(icon='shopping-cart',color='gray'),tooltip='Emart').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e52875077b8d1fdc750ea283d8e92f34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e52875077b8d1fdc750ea283d8e92f34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e52875077b8d1fdc750ea283d8e92f34 = L.map(
#                 &quot;map_e52875077b8d1fdc750ea283d8e92f34&quot;,
#                 {
#                     center: [35.2500198, 129.0907241],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00320a1c59f57ad9b18cc7dc345c072c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var marker_9a24f9c78e3b486460bc3c0b71753569 = L.marker(
#                 [37.4782316, 127.1193703],
#                 {&quot;color&quot;: &quot;gray&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var icon_8cece5761ca9e11d4ce7bed5dadae733 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a24f9c78e3b486460bc3c0b71753569.setIcon(icon_8cece5761ca9e11d4ce7bed5dadae733);
#
#
#             marker_9a24f9c78e3b486460bc3c0b71753569.bindTooltip(
#                 `&lt;div&gt;
#                      Emart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d18a81726252c97bcb08a8d2c5408e2c = L.marker(
#                 [37.5578966, 126.8622978],
#                 {&quot;color&quot;: &quot;gray&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var icon_836aeec5061fae8ab9e42ce211c1570c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d18a81726252c97bcb08a8d2c5408e2c.setIcon(icon_836aeec5061fae8ab9e42ce211c1570c);
#
#
#             marker_d18a81726252c97bcb08a8d2c5408e2c.bindTooltip(
#                 `&lt;div&gt;
#                      Emart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e2309a32e967bd3129b8e505766616c = L.marker(
#                 [37.7705833, 128.9226176],
#                 {&quot;color&quot;: &quot;gray&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var icon_a803582bc27020412355de6a31e56baa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e2309a32e967bd3129b8e505766616c.setIcon(icon_a803582bc27020412355de6a31e56baa);
#
#
#             marker_1e2309a32e967bd3129b8e505766616c.bindTooltip(
#                 `&lt;div&gt;
#                      Emart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9ee8afa14d72bed4f93f60a7bd0b133 = L.marker(
#                 [37.5855344, 126.6771944],
#                 {&quot;color&quot;: &quot;gray&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var icon_1adedfba90a749490a6d20315025717d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f9ee8afa14d72bed4f93f60a7bd0b133.setIcon(icon_1adedfba90a749490a6d20315025717d);
#
#
#             marker_f9ee8afa14d72bed4f93f60a7bd0b133.bindTooltip(
#                 `&lt;div&gt;
#                      Emart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d374a8ef23c6c8dbca23438c1117e899 = L.marker(
#                 [37.409522, 127.2612286],
#                 {&quot;color&quot;: &quot;gray&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_e52875077b8d1fdc750ea283d8e92f34);
#
#
#             var icon_0441ffea23b71628269d187eb4bb46ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;shopping-cart&quot;, &quot;iconColor&quot;: &quo
