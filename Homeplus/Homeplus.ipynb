# %%
import time
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.font_manager as fm
import urllib.request


from selenium.webdriver.common.by import By
from selenium import webdriver
from matplotlib import rc
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option('excludeSwitches', ['enable-logging'])
wd = webdriver.Chrome('./chromedriver.exe',options=options)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_19576\1218337680.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome('./chromedriver.exe',options=options)

# %%
wd.get('https://corporate.homeplus.co.kr/STORE/HyperMarket.aspx')
time.sleep(0.3)

homeplus_info = []

for i in range(1,135):
    wd.find_element(By.XPATH,'//*[@id="ctl00_ContentPlaceHolder1_Region_Code"]/option[2]').click() 
    time.sleep(0.3) #서울특별시 클릭
    wd.find_element(By.XPATH,'//*[@id="ctl00_ContentPlaceHolder1_Region_Code"]/option[1]').click() #서울특별시 클릭
    time.sleep(0.3) #전체 클릭
    # wd.find_element(By.XPATH, '//*[@id="content"]/div/div/div/div[1]/div[2]/div[2]/input[2]').click()
    # time.sleep(0.3) #클릭 후 돋보기
    wd.find_element(By.XPATH,f'//*[@id="content"]/div/div/div/ul/li[{i}]/div[1]/h3/span[2]/a').click()
    time.sleep(1)
    html = wd.page_source
    soup = BeautifulSoup(html, 'html.parser')
    store_name = soup.select('div.col-lg-4 > h3.type > span.name')[0].string.strip()
    store_address = soup.select('div.tab-content > div#store_detail01 > table.table > tbody > tr > td')[0].string.rstrip()
    store_phone = soup.select('div.tab-content > div#store_detail01 > table.table > tbody > tr > td')[2].string.strip()
    homeplus_info.append([store_name]+[store_address]+[store_phone])

    wd.find_element(By.XPATH,'//*[@id="content"]/div/div/div/div[3]/a').click()
    time.sleep(0.3)

# %%
homeplus_info
# Out:
# [['가양점', '서울특별시 강서구 양천로 431', '02-2063-2080'],
#  ['가좌점', '인천광역시 서구 가정로 151번길 11', '032-453-8000'],
#  ['간석점', '인천광역시 남동구 경원대로 971', '032-870-8000'],
#  ['강동점', '서울특별시 강동구 양재대로 1571(메르디안 쇼핑센터)', '02-3400-8000'],
#  ['강릉점', '강원도 강릉시 경강로 2120', '033-649-8000'],
#  ['강서점', '서울특별시 강서구 화곡로 398', '02-2660-8000'],
#  ['거제점', '경상남도 거제시 장평로 12', '055-686-8000'],
#  ['경기하남점', '경기도 하남시 하남대로 747', '031-777-7000'],
#  ['경산점', '경상북도 경산시 경안로 288', '053-715-8000'],
#  ['경주점', '경상북도 경주시 공단로 97', '054-770-8000'],
#  ['계룡점', '충청남도 계룡시 계룡대로 304', '042-550-8000'],
#  ['계산점', '인천광역시 계양구 오조산 공원로 14', '032-551-2080'],
#  ['고양터미널점', '경기도 고양시 일산동구 중앙로 1036', '031-936-7800'],
#  ['광양점', '전라남도 광양시 항만11로 70', '061-760-8000'],
#  ['광주계림점', '광주광역시 동구 무등로 314', '062-530-8000'],
#  ['광주하남점', '광주광역시 광산구 용아로 390', '062-616-8000'],
#  ['구미점', '경상북도 구미시 구미대로 174', '054-459-8000'],
#  ['구월점', '인천광역시 남동구 예술로 198', '032-428-2080'],
#  ['금천점', '서울특별시 금천구 시흥대로 391', '02-890-8000'],
#  ['김제점', '전라북도 김제시 금성로 114', '063-540-8000'],
#  ['김포점', '경기도 김포시 중봉로 14', '031-999-8000'],
#  ['김포풍무점', '경기도 김포시 풍무로 167', '031-999-0000'],
#  ['김해점', '경상남도 김해시 김해대로 2078', '055-320-8000'],
#  ['남대구점', '대구광역시 남구 대명로 116', '053-659-8000'],
#  ['내당점', '대구광역시 서구 달구벌대로 1821', '053-567-2080'],
#  ['논산점', '충청남도 논산시 시민로 187', '041-731-8000'],
#  ['대구수성점', '대구광역시 수성구 동대구로 95', '053-760-8000'],
#  ['대전가오점', '대전광역시 동구 은어송로 72', '042-281-8000'],
#  ['동광주점', '광주광역시 북구 동문대로 200', '062-250-8000'],
#  ['동대문점', '서울특별시 동대문구 천호대로 133', '02-2173-8000'],
#  ['동대전점', '대전광역시 동구 한밭대로 1282', '042-608-8000'],
#  ['동래점', '부산광역시 동래구 중앙대로 1523', '051-559-8000'],
#  ['동수원점', '경기도 수원시 팔달구 효원로 257', '031-231-8000'],
#  ['동청주점', '충청북도 청주시 청원구 충청대로 114 지하1층', '043-290-8000'],
#  ['동촌점', '대구광역시 동구 동촌로 127', '053-559-2080'],
#  ['마산점', '경상남도 창원시 마산회원구 삼호로 56', '055-259-8000'],
#  ['면목점', '서울시 중랑구 사가정로 332 (면목동)', '02-437-2080'],
#  ['목동점', '서울특별시 양천구 목동서로 170', '02-2644-2080'],
#  ['목포점', '전라남도 목포시 영산로 313', '061-241-8000'],
#  ['문경점', '경상북도 문경시 모전로 65', '054-559-8000'],
#  ['문화점', '대전광역시 중구 계백로 1690', '042-226-2080'],
#  ['밀양점', '경상남도 밀양시 점필재로 45', '055-359-8000'],
#  ['방학점', '서울특별시 도봉구 도봉로 678', '02-912-2080'],
#  ['병점점', '경기도 화성시 경기대로 985', '031-283-2080'],
#  ['보령점', '충청남도 보령시 명암1길 17', '041-939-8000'],
#  ['부산감만점', '부산광역시 남구 우암로 124', '051-609-8000'],
#  ['부산반여점', '부산광역시 해운대구 선수촌로21번길 37  (반여동)', '051-509-8000'],
#  ['부산연산점', '부산시 연제구 연산동 105-1', '051-850-8000'],
#  ['부산정관점', '부산광역시 기장군 정관면 정관5로 50', '051-519-8200'],
#  ['부천상동점', '경기도 부천시 원미구 길주로 118', '032-650-8000'],
#  ['부천소사점', '경기도 부천시 소사구 경인로 532', '032-610-8000'],
#  ['부천여월점', '경기도 부천시 오정구 소사로 663', '032-680-8000'],
#  ['북수원점', '경기도 수원시 장안구 경수대로 930', '031-259-8000'],
#  ['분당오리점', '경기도 성남시 분당구 구미동 159', '031-884-2080'],
#  ['삼척점', '강원도 삼척시 중앙로 258', '033-571-8000'],
#  ['삼천포점', '경상남도 사천시 중앙로 165', '055-831-8000'],
#  ['상인점', '대구광역시 달서구 월배로 183', '053-380-8000'],
#  ['서귀포점', '제주특별자치도 서귀포시 중앙로 180', '064-731-8114'],
#  ['서대전점', '대전광역시 유성구 대정로 23', '042-540-8000'],
#  ['서면점', '부산광역시 부산진구 동천로 4', '051-644-2080'],
#  ['서부산점', '부산광역시 사상구 광장로 7', '051-319-8000'],
#  ['서수원점', '경기도 수원시 권선구 금곡동 160', '031-8019-1000'],
#  ['서울남현점', '서울시 관악구 과천대로 909', '02-6948-8000'],
#  ['서울상봉점', '서울특별시 중랑구 망우로 353', '02-6922-8100'],
#  ['성서점', '대구광역시 달서구 달구벌대로 1467', '053-550-8000'],
#  ['세종점', '세종특별자치시 절재로 154', '044-715-8000'],
#  ['센텀시티점', '부산광역시 해운대구 센텀동로 6', '051-709-8000'],
#  ['송탄점', '경기도 평택시 경기대로 1103', '031-8053-8000'],
#  ['순천점', '전라남도 순천시 신월큰길 10', '061-729-8000'],
#  ['순천풍덕점', '전라남도 순천시 팔마로 222', '061-746-2080'],
#  ['시화점', '경기도 시흥시 희망공원로 269', '031-310-8000'],
#  ['시흥점', '서울특별시 금천구 시흥대로 201', '02-895-2080'],
#  ['신내점', '서울특별시 중랑구 신내로 201', '02-2024-8000'],
#  ['신도림점', '서울특별시 구로구 경인로 661', '02-2618-2080'],
#  ['아시아드점', '부산광역시 연제구 종합운동장로 7', '051-500-8000'],
#  ['안동점', '경상북도 안동시 경동로 656', '054-840-8300'],
#  ['안산고잔점', '경기도 안산시 단원구 광덕대로 175', '031-445-2080'],
#  ['안산선부점', '경기도 안산시 단원구 삼일로 316', '031-400-8000'],
#  ['안양점', '경기도 안양시 동안구 엘에스로 92', '031-459-2080'],
#  ['야탑점', '경기도 성남시 분당구 성남대로925번길 16', '031-705-2080'],
#  ['영도점', '부산광역시 영도구 대교로14번길 57', '051-419-8000'],
#  ['영등포점', '서울특별시 영등포구 당산로 42', '02-2165-8000'],
#  ['영주점', '경상북도 영주시 대학로 29', '054-630-8000'],
#  ['영통점', '경기도 수원시 영통구 봉영로 1576', '031-201-8000'],
#  ['오산점', '경기도 오산시 수청동 252', '031-8077-8800'],
#  ['오창점', '충청북도 청원군 오창읍 중심상업1로 8-11', '043-249-8000'],
#  ['울산남구점', '울산광역시 남구 수암로 148', '052-270-8000'],
#  ['울산동구점', '울산광역시 동구 방어진 순환도로 637', '052-230-8000'],
#  ['울산북구점', '울산광역시 북구 신답로 26', '052-293-2080'],
#  ['울산점', '울산광역시 중구 번영로 475', '052-290-8000'],
#  ['원주점', '강원 원주시 치악로 1489', '033-769-8700'],
#  ['원천점', '경기도 수원시 영통구 중부대로 437', '031-252-2080'],
#  ['월곡점', '서울특별시 성북구 화랑로 76', '02-3669-8000'],
#  ['월드컵점', '서울시 마포구 성산동 515 홈플러스월드컵점', '02-312-2080'],
#  ['유성점', '대전광역시 유성구 한밭대로 502', '042-841-2080'],
#  ['의정부점', '경기도 의정부시 청사로 38', '031-850-8000'],
#  ['익산점', '전라북도 익산시 무왕로 1035', '063-859-8000'],
#  ['인천논현점', '인천광역시 남동구 청능대로 596', '032-455-8000'],
#  ['인천송도점', '인천광역시 연수구 송도동 168-3', '032-834-8543'],
#  ['인천숭의점', '인천광역시 남구 석정로 51', '032-719-2000'],
#  ['인천연수점', '인천광역시 연수구 청능대로 210', '032-430-8000'],
#  ['인천청라점', '인천광역시 서구 중봉대로 587', '032-723-8800'],
#  ['인하점', '인천시 미추홀구 소성로 6', '032-763-2080'],
#  ['일산점', '경기도 고양시 일산동구 중앙로 1275번길 64', '031-925-2080'],
#  ['작전점', '인천광역시 계양구 계양대로 27', '032-540-8000'],
#  ['잠실점', '서울특별시 송파구 올림픽로35가길 16', '02-3468-8000'],
#  ['장림점', '부산광역시 사하구 다대로 225', '051-466-2080'],
#  ['전주완산점', '전라북도 전주시 완산구 기린대로 170', '063-263-2080'],
#  ['전주점', '전라북도 전주시 덕진구 백제대로 771', '063-249-8000'],
#  ['전주효자점', '전라북도 전주시 완산구 용머리로 31', '063-281-8000'],
#  ['조치원점', '세종특별자치시 조치원읍 허만석로 60', '044-861-8100'],
#  ['죽도점', '경상북도 포항시 북구 중흥로 328', '054-288-8000'],
#  ['중계점', '서울특별시 노원구 동일로 204가길 12', '02-986-2080'],
#  ['진접점', '경기도 남양주시 진접읍 장현리 216-1', '031-570-8000'],
#  ['진주점', '경상남도 진주시 대신로 304', '055-771-8000'],
#  ['진해점', '경상남도 창원시 진해구 충장로 356', '055-540-8000'],
#  ['창원점', '경상남도 창원시 의창구 창원대로 415', '055-270-8000'],
#  ['천안신방점', '충청남도 천안시 동남구 신촌1길 23', '041-552-2080'],
#  ['천안점', '충청남도 천안시 동남구 천안대로 574 (구성동)', '041-590-8000'],
#  ['청주성안점', '충청북도 청주시 상당구 사직대로 346', '043-259-2080'],
#  ['청주점', '충청북도 청주시 흥덕구 서부로 1291', '043-251-8000'],
#  ['춘천점', '강원도 춘천시 김유정로 1840', '033-269-8000'],
#  ['칠곡점', '대구광역시 북구 동암로12길 8', '053-607-8000'],
#  ['킨텍스점', '경기도 고양시 일산서구 호수로 817', '031-960-7000'],
#  ['파주문산점', '경기도 파주시 문산읍 방촌로 1759', '031-960-8000'],
#  ['파주운정점', '경기도 파주시 청암로 17번길 17 (목동동927번지)', '031-8035-1300'],
#  ['평촌점', '경기도 안양시 동안구 동안로 162', '031-470-8000'],
#  ['평택안중점', '경기도 평택시 안중읍 서동대로 1489', '031-8046-8200'],
#  ['포천송우점', '경기도 포천시 소흘읍 솔모루로 9', '031-540-7000'],
#  ['포항점', '경상북도 포항시 남구 중흥로 77', '054-249-2080'],
#  ['합정점', '서울시 마포구 양화로 45', '02-6938-8800'],
#  ['해운대점', '부산광역시 해운대구 해운대해변로 140', '051-532-2080'],
#  ['화성동탄점', '경기도 화성시 동탄중앙로 200', '031-8015-7000'],
#  ['화성향남점', '경기도 화성시 향남읍 향남로 402', '031-8059-8700']]

# %%
type(homeplus_info)
# Out:
# list

# %%
columns = ['store','address', 'tel']
homeplus_df = pd.DataFrame(homeplus_info, columns=columns)

# %%
homeplus_df
# Out:
#      store                         address            tel
# 0      가양점               서울특별시 강서구 양천로 431   02-2063-2080
# 1      가좌점           인천광역시 서구 가정로 151번길 11   032-453-8000
# 2      간석점              인천광역시 남동구 경원대로 971   032-870-8000
# 3      강동점  서울특별시 강동구 양재대로 1571(메르디안 쇼핑센터)   02-3400-8000
# 4      강릉점                강원도 강릉시 경강로 2120   033-649-8000
# ..     ...                             ...            ...
# 129    포항점              경상북도 포항시 남구 중흥로 77   054-249-2080
# 130    합정점                  서울시 마포구 양화로 45   02-6938-8800
# 131   해운대점           부산광역시 해운대구 해운대해변로 140   051-532-2080
# 132  화성동탄점               경기도 화성시 동탄중앙로 200  031-8015-7000
# 133  화성향남점             경기도 화성시 향남읍 향남로 402  031-8059-8700
#
# [134 rows x 3 columns]

# %%
homeplus_df.to_csv('./Homeplus_shop_info.csv', index=True, encoding='utf-8')
print('저장완료')
# Out:
# 저장완료

# %%
data = pd.read_csv('./Homeplus_shop_info_loc.csv', index_col=0, encoding='utf-8')
data
# Out:
#      store                         address   Latitude   Longitude  \
# 0      가양점               서울특별시 강서구 양천로 431  37.564245  126.849942
# 1      가좌점           인천광역시 서구 가정로 151번길 11  37.497567  126.670690
# 2      간석점              인천광역시 남동구 경원대로 971  37.469524  126.689069
# 3      강동점  서울특별시 강동구 양재대로 1571(메르디안 쇼핑센터)  37.545658  127.142244
# 4      강릉점                강원도 강릉시 경강로 2120  37.755659  128.898621
# ..     ...                             ...        ...         ...
# 129    포항점              경상북도 포항시 남구 중흥로 77  36.012751  129.348903
# 130    합정점                  서울시 마포구 양화로 45  37.548966  126.913477
# 131   해운대점           부산광역시 해운대구 해운대해변로 140  35.158433  129.146451
# 132  화성동탄점               경기도 화성시 동탄중앙로 200  37.202769  127.068491
# 133  화성향남점             경기도 화성시 향남읍 향남로 402  37.130696  126.921848
#
#                tel
# 0     02-2063-2080
# 1     032-453-8000
# 2     032-870-8000
# 3     02-3400-8000
# 4     033-649-8000
# ..             ...
# 129   054-249-2080
# 130   02-6938-8800
# 131   051-532-2080
# 132  031-8015-7000
# 133  031-8059-8700
#
# [134 rows x 5 columns]

# %%
data = data.insert(0,'store1', '홈플러스')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\MartRepository\4Mart\Homeplus\Homeplus.ipynb 셀 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/MartRepository/4Mart/Homeplus/Homeplus.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> data = data.insert(0,'store1', '홈플러스')
#
# AttributeError: 'NoneType' object has no attribute 'insert'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\MartRepository\4Mart\Homeplus\Homeplus.ipynb 셀 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/MartRepository/4Mart/Homeplus/Homeplus.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
