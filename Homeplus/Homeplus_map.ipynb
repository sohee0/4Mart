# %%
import time
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.font_manager as fm
import urllib.request
import folium


from selenium.webdriver.common.by import By
from selenium import webdriver
from matplotlib import rc
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
homeplus_df = pd.read_csv('./Homeplus_shop_info_loc4.csv', encoding='utf-8')
homeplus_df.head()
# Out:
#       store                         address   Latitude   Longitude  \
# 0  홈플러스 가양점               서울특별시 강서구 양천로 431  37.564245  126.849942
# 1  홈플러스 가좌점           인천광역시 서구 가정로 151번길 11  37.497567  126.670690
# 2  홈플러스 간석점              인천광역시 남동구 경원대로 971  37.469524  126.689069
# 3  홈플러스 강동점  서울특별시 강동구 양재대로 1571(메르디안 쇼핑센터)  37.545658  127.142244
# 4  홈플러스 강릉점                강원도 강릉시 경강로 2120  37.755659  128.898621
#
#             tel
# 0  02-2063-2080
# 1  032-453-8000
# 2  032-870-8000
# 3  02-3400-8000
# 4  033-649-8000

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=16,tiles='OpenStreetMap')
folium.Marker(location=[35.2217998,129.0858061],icon=folium.Icon(color='red',icon='home'),tooltip='홈플러스').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=10,tiles='OpenStreetMap')

for i in homeplus_df.index:
    home_lat = homeplus_df.loc[i,'Latitude']
    home_long = homeplus_df.loc[i,'Longitude']

    title = f"{homeplus_df.loc[i, 'store']} - {homeplus_df.loc[i, 'address']}"

    color = 'red'
    if homeplus_df.loc[i,'store']=='홈플러스':
        color ='red'

    folium.Marker(location=[home_lat,home_long],radius=5,color=color,icon=folium.Icon(icon='home',color='red'),tooltip='홈플러스').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=10,tiles='OpenStreetMap')

for i in homeplus_df.index:
    home_lat = homeplus_df.loc[i,'Latitude']
    home_long = homeplus_df.loc[i,'Longitude']

    title = f"{homeplus_df.loc[i, 'store']}"

    color = 'red'
    if homeplus_df.loc[i,'store']=='홈플러스':
        color ='red'

    folium.Marker(location=[home_lat,home_long],radius=5,color=color,icon=folium.Icon(icon='home',color='red'),tooltip=title).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=10,tiles='OpenStreetMap')

for i in homeplus_df.index:
    home_lat = homeplus_df.loc[i,'Latitude']
    home_long = homeplus_df.loc[i,'Longitude']

    name = f"{homeplus_df.loc[i, 'store']}"
    address = f"{homeplus_df.loc[i, 'address']}"
    tel = f"{homeplus_df.loc[i, 'tel']}"

    color = 'red'
    if homeplus_df.loc[i,'store']=='홈플러스':
        color ='red'

    folium.Marker(location=[home_lat,home_long],radius=5,color=color,icon=folium.Icon(icon='home',color='red'),popup=f'<pre>{name}\\n 주소: {address}\\n Tel: {tel}</pre>').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
