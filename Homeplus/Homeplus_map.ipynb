# %%
import time
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.font_manager as fm
import urllib.request
import folium


from selenium.webdriver.common.by import By
from selenium import webdriver
from matplotlib import rc
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
homeplus_df = pd.read_csv('./Homeplus_shop_info_loc4.csv', encoding='utf-8')
homeplus_df.head()
# Out:
#       store                         address   Latitude   Longitude  \
# 0  홈플러스 가양점               서울특별시 강서구 양천로 431  37.564245  126.849942
# 1  홈플러스 가좌점           인천광역시 서구 가정로 151번길 11  37.497567  126.670690
# 2  홈플러스 간석점              인천광역시 남동구 경원대로 971  37.469524  126.689069
# 3  홈플러스 강동점  서울특별시 강동구 양재대로 1571(메르디안 쇼핑센터)  37.545658  127.142244
# 4  홈플러스 강릉점                강원도 강릉시 경강로 2120  37.755659  128.898621
#
#             tel
# 0  02-2063-2080
# 1  032-453-8000
# 2  032-870-8000
# 3  02-3400-8000
# 4  033-649-8000

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=16,tiles='OpenStreetMap')
folium.Marker(location=[35.2217998,129.0858061],icon=folium.Icon(color='red',icon='home'),tooltip='홈플러스').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd674459de1860e057e04faf0980826e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd674459de1860e057e04faf0980826e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cd674459de1860e057e04faf0980826e = L.map(
#                 &quot;map_cd674459de1860e057e04faf0980826e&quot;,
#                 {
#                     center: [35.2217998, 129.0858061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de348b2266523759e299da0cadcf6942 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cd674459de1860e057e04faf0980826e);
#
#
#             var marker_86f7903226b0741533d902991c0b2b22 = L.marker(
#                 [35.2217998, 129.0858061],
#                 {}
#             ).addTo(map_cd674459de1860e057e04faf0980826e);
#
#
#             var icon_7b44fc68ce7c89dd2236c44a27b1d932 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86f7903226b0741533d902991c0b2b22.setIcon(icon_7b44fc68ce7c89dd2236c44a27b1d932);
#
#
#             marker_86f7903226b0741533d902991c0b2b22.bindTooltip(
#                 `&lt;div&gt;
#                      홈플러스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[35.2217998,129.0858061],zoom_start=10,tiles='OpenStreetMap')

for i in homeplus_df.index:
    home_lat = homeplus_df.loc[i,'Latitude']
    home_long = homeplus_df.loc[i,'Longitude']

    title = f"{homeplus_df.loc[i, 'store']} - {homeplus_df.loc[i, 'address']}"

    color = 'red'
    if homeplus_df.loc[i,'store']=='홈플러스':
        color ='red'

    folium.Marker(location=[home_lat,home_long],radius=5,color=color,icon=folium.Icon(icon='home',color='red'),tooltip='홈플러스').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e2386ead1bfa45f17944f9f16b7bf8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e2386ead1bfa45f17944f9f16b7bf8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8e2386ead1bfa45f17944f9f16b7bf8c = L.map(
#                 &quot;map_8e2386ead1bfa45f17944f9f16b7bf8c&quot;,
#                 {
#                     center: [35.2217998, 129.0858061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fe4dddafb298f6034905adb144770a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var marker_13248c59166c978c34154c9b5b0060c3 = L.marker(
#                 [37.5642454, 126.8499416],
#                 {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var icon_51e8867f787777c0502c5fda821e006a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13248c59166c978c34154c9b5b0060c3.setIcon(icon_51e8867f787777c0502c5fda821e006a);
#
#
#             marker_13248c59166c978c34154c9b5b0060c3.bindTooltip(
#                 `&lt;div&gt;
#                      홈플러스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_93a334bea531b7a5f83b7dab4083b7a6 = L.marker(
#                 [37.4975674, 126.6706903],
#                 {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var icon_8b3dca478e2462d97b27ff3b39be2226 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93a334bea531b7a5f83b7dab4083b7a6.setIcon(icon_8b3dca478e2462d97b27ff3b39be2226);
#
#
#             marker_93a334bea531b7a5f83b7dab4083b7a6.bindTooltip(
#                 `&lt;div&gt;
#                      홈플러스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_15af3a62894b158fa0865e109bb1b72b = L.marker(
#                 [37.4695239, 126.6890686],
#                 {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var icon_c50ce3a404a7983c8291dfe3c93fdec6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_15af3a62894b158fa0865e109bb1b72b.setIcon(icon_c50ce3a404a7983c8291dfe3c93fdec6);
#
#
#             marker_15af3a62894b158fa0865e109bb1b72b.bindTooltip(
#                 `&lt;div&gt;
#                      홈플러스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ca73e36f70b014a5a66e64691e199d0d = L.marker(
#                 [37.5456582, 127.1422439],
#                 {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var icon_949bde49b6e54ef0e10033b8fdfe5cdf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca73e36f70b014a5a66e64691e199d0d.setIcon(icon_949bde49b6e54ef0e10033b8fdfe5cdf);
#
#
#             marker_ca73e36f70b014a5a66e64691e199d0d.bindTooltip(
#                 `&lt;div&gt;
#                      홈플러스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ab8942f3f318ef5d1ccca242f8c68876 = L.marker(
#                 [37.7556587, 128.8986211],
#                 {&quot;color&quot;: &quot;red&quot;, &quot;radius&quot;: 5}
#             ).addTo(map_8e2386ead1bfa45f17944f9f16b7bf8c);
#
#
#             var icon_3ad17e4d62900c8aabeca03069fcee83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;,
